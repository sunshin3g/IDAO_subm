# %%
# !pip install torch==1.9.0+cu111 -f https://download.pytorch.org/whl/cu111/torch_stable.html
# !pip install torchvision==0.10.0
# !pip install numpy
# !pip install scipy
# !pip install matplotlib
# !pip install pickle5
# !pip install joblib
# !pip install dscribe
# !pip install scikit-learn
# !pip install ray[default]
# !pip install hyperopt
# !pip install tensorboardX
# !pip install pymatgen==v2021.3.3
# !pip install ase
# !pip install -U PyYAML

# %%
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.9.0+cu111.html
# !pip install torch-sparse -f https://pytorch-geometric.com/whl/torch-1.9.0+cu111.html
# !pip install torch-cluster -f https://pytorch-geometric.com/whl/torch-1.9.0+cu111.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.9.0+cu111.html
# !pip install torch-geometric

# %%
# !unzip fb.zip

# %%
# !nvidia-smi
# Out:
# Fri Feb 25 21:20:12 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# Predictions take about 500sec total on P100

# %%
# !python deeperGATGNN/main.py --reprocess="True" --data_path='cif_private' --format="cif" --job_name="mod0" --run_mode='Predict' --model_path='./models/mod0.pth' --config_path='./deeperGATGNN/config.yml' --batch_size='10' --seed="666"
# Out:
# Starting...
# GPU is available: True , Quantity:  1
# Settings:
# {'Job': {'job_name': 'mod0',
#          'model_path': './models/mod0.pth',
#          'reprocess': 'True',
#          'seed': 666,
#          'write_output': 'True'},
#  'Models': {},
#  'Processing': {'SM_descriptor': 'False',
#                 'SOAP_descriptor': 'False',
#                 'SOAP_lmax': 4,
#                 'SOAP_nmax': 6,
#                 'SOAP_rcut': 8.0,
#                 'SOAP_sigma': 0.3,
#                 'data_format': 'cif',
#                 'data_path': 'cif_private',
#                 'dataset_type': 'inmemory',
#                 'dictionary_path': 'atom_dict.json',
#                 'dictionary_source': 'default',
#                 'edge_features': 'True',
#                 'graph_edge_length': 50,
#                 'graph_max_neighbors': 12,
#                 'graph_max_radius': 8.0,
#                 'target_path': 'targets.csv',
#                 'verbose': 'True',
# ...

# %%
# !python deeperGATGNN/main.py --reprocess="False" --data_path='cif_private' --format="cif" --job_name="mod11" --run_mode='Predict' --model_path='./models/mod11.pth' --config_path='./deeperGATGNN/config.yml' --batch_size='10' --seed='666'
# Out:
# Starting...
# GPU is available: True , Quantity:  1
# Settings:
# {'Job': {'job_name': 'mod11',
#          'model_path': './models/mod11.pth',
#          'reprocess': 'False',
#          'seed': 666,
#          'write_output': 'True'},
#  'Models': {},
#  'Processing': {'SM_descriptor': 'False',
#                 'SOAP_descriptor': 'False',
#                 'SOAP_lmax': 4,
#                 'SOAP_nmax': 6,
#                 'SOAP_rcut': 8.0,
#                 'SOAP_sigma': 0.3,
#                 'data_format': 'cif',
#                 'data_path': 'cif_private',
#                 'dataset_type': 'inmemory',
#                 'dictionary_path': 'atom_dict.json',
#                 'dictionary_source': 'default',
#                 'edge_features': 'True',
#                 'graph_edge_length': 50,
#                 'graph_max_neighbors': 12,
#                 'graph_max_radius': 8.0,
#                 'target_path': 'targets.csv',
#                 'verbose': 'True',
# ...

# %%
# !python deeperGATGNN/main.py --reprocess="False" --data_path='cif_private' --format="cif" --job_name="mod14" --run_mode='Predict' --model_path='./models/mod14.pth' --config_path='./deeperGATGNN/config.yml' --batch_size='10' --seed='666'
# Out:
# Starting...
# GPU is available: True , Quantity:  1
# Settings:
# {'Job': {'job_name': 'mod14',
#          'model_path': './models/mod14.pth',
#          'reprocess': 'False',
#          'seed': 666,
#          'write_output': 'True'},
#  'Models': {},
#  'Processing': {'SM_descriptor': 'False',
#                 'SOAP_descriptor': 'False',
#                 'SOAP_lmax': 4,
#                 'SOAP_nmax': 6,
#                 'SOAP_rcut': 8.0,
#                 'SOAP_sigma': 0.3,
#                 'data_format': 'cif',
#                 'data_path': 'cif_private',
#                 'dataset_type': 'inmemory',
#                 'dictionary_path': 'atom_dict.json',
#                 'dictionary_source': 'default',
#                 'edge_features': 'True',
#                 'graph_edge_length': 50,
#                 'graph_max_neighbors': 12,
#                 'graph_max_radius': 8.0,
#                 'target_path': 'targets.csv',
#                 'verbose': 'True',
# ...

# %%
# !python deeperGATGNN/main.py --reprocess="False" --data_path='cif_private' --format="cif" --job_name="mod6" --run_mode='Predict' --model_path='./models/mod6.pth' --config_path='./deeperGATGNN/config.yml' --batch_size='10' --seed='666'
# Out:
# Starting...
# GPU is available: True , Quantity:  1
# Settings:
# {'Job': {'job_name': 'mod6',
#          'model_path': './models/mod6.pth',
#          'reprocess': 'False',
#          'seed': 666,
#          'write_output': 'True'},
#  'Models': {},
#  'Processing': {'SM_descriptor': 'False',
#                 'SOAP_descriptor': 'False',
#                 'SOAP_lmax': 4,
#                 'SOAP_nmax': 6,
#                 'SOAP_rcut': 8.0,
#                 'SOAP_sigma': 0.3,
#                 'data_format': 'cif',
#                 'data_path': 'cif_private',
#                 'dataset_type': 'inmemory',
#                 'dictionary_path': 'atom_dict.json',
#                 'dictionary_source': 'default',
#                 'edge_features': 'True',
#                 'graph_edge_length': 50,
#                 'graph_max_neighbors': 12,
#                 'graph_max_radius': 8.0,
#                 'target_path': 'targets.csv',
#                 'verbose': 'True',
# ...

# %%
# !python deeperGATGNN/main.py --reprocess="False" --data_path='cif_private' --format="cif" --job_name="mod8" --run_mode='Predict' --model_path='./models/mod8.pth' --config_path='./deeperGATGNN/config.yml' --batch_size='10' --seed='666'
# Out:
# Starting...
# GPU is available: True , Quantity:  1
# Settings:
# {'Job': {'job_name': 'mod8',
#          'model_path': './models/mod8.pth',
#          'reprocess': 'False',
#          'seed': 666,
#          'write_output': 'True'},
#  'Models': {},
#  'Processing': {'SM_descriptor': 'False',
#                 'SOAP_descriptor': 'False',
#                 'SOAP_lmax': 4,
#                 'SOAP_nmax': 6,
#                 'SOAP_rcut': 8.0,
#                 'SOAP_sigma': 0.3,
#                 'data_format': 'cif',
#                 'data_path': 'cif_private',
#                 'dataset_type': 'inmemory',
#                 'dictionary_path': 'atom_dict.json',
#                 'dictionary_source': 'default',
#                 'edge_features': 'True',
#                 'graph_edge_length': 50,
#                 'graph_max_neighbors': 12,
#                 'graph_max_radius': 8.0,
#                 'target_path': 'targets.csv',
#                 'verbose': 'True',
# ...

# %% [markdown]
# # Submission

# %%
import pandas as pd

# %%
preds = []
for mod in ["mod0", "mod11", "mod14", "mod6", "mod8"]:
  preds.append(pd.read_csv(mod + "_predicted_outputs.csv")[["ids", "prediction"]].rename({"ids": "id", "prediction": "predictions"}, axis=1))

# %%
subm = preds[0]
subm["predictions"] = (subm["predictions"] + preds[1]["predictions"] + preds[2]["predictions"] + preds[3]["predictions"] + preds[4]["predictions"])/5

# %%
subm.head()
# Out:
#                          id  predictions
# 0  6141dc9f3ac25c70a5c6c955     0.421052
# 1  6141d06f4e27a1844a5f00cc     1.146276
# 2  6141cf35b842c2e72e2f2d66     1.809101
# 3  6141dd364e27a1844a5f02ba     1.139576
# 4  6142d13a3ac25c70a5c6cc53     0.417345

# %%
subm.to_csv("final_submission.csv", index=False)
